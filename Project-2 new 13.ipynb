# %% [markdown]
# # Wheelchair Control
#
# ![](images/wheelchair.jpg)

# %% [markdown]
# ### Python Dependencies

# %%
from numpy import *
from numpy.linalg import *

from scipy.linalg import *
from scipy.integrate import *
from scipy.signal import *

from matplotlib.pyplot import *

# %% [markdown]
# Step 1 - Wheelchair Planar Model
# ================================

# %% [markdown]
# ### Introduction

# %% [markdown]
# We consider a simple model of a wheelchair evolving in the plane. It is mainly made of
#
#   - A frame ; from above, its most visible component is the seat. We assume that it is a square,
#
#   - Two fixed wheels (their orientation with respect to the frame does not change).
#     They are parallel and located at opposite ends of the seat.
#
# We assume that the seat backrest is on top of the wheels common axis.
#
#
# Let $(0, e_x, e_y)$ be a direct orthonormal frame of the plane. We denote
#
#   - $(x, y)$ the coordinates of the wheel axis center in the orthonormal and
#   - $\theta$ the angle of the wheels direction with respect to vector $e_x$ ; with $\theta = 0$ when the front of the wheelchait faces the right ($e_x$) and $\theta = \pi/2$ when it faces upwards ($e_y$).
#
#   - $\phi_l$ and $\phi_r$ the rotation angles of the left and right wheel respectively ; by convention, when these angles increase, the wheelchair moves forward.

# %% [markdown]
# ### Parameter Definition

# %% [markdown]
# From now on, we assume that the seat side length is $L = 50 \mbox{ cm}$ and the wheel radius is $R_w = 30 \mbox{ cm}$.
#
# 🧩 Define the corresponding Python variables `L` and `Rw` (express every length in meters, and more generally in the sequel, always use the [international standard of units](https://en.wikipedia.org/wiki/SI_derived_unit)) for numerical values.

# %%
# 🔓
L = 50 / 100
Rw = 30 / 100

# %% [markdown]
# ### Graphical Representation
#
# 🧩 Implement a function `draw_wheelchair` with arguments `x`, `y` and `theta` that draws a simple geometric model of the wheelchair (with seat and fixed wheels) in the plane (top view) for arbitrary values of $(x, y)$ and $\theta$.
#
# 🗝️ **Hint.** Use the function `plot` of `matplotlib.pyplot`.

# %%
# 🔓
def draw_wheelchair(x, y, theta):
    translation = array([[x], [y]])
    rotation = array([
        [cos(theta), -sin(theta)], 
        [sin(theta),  cos(theta)]
    ])

    # Seat
    corners = [[0, -L/2], [L, -L/2], [L, +L/2], [0, L/2]]
    corners += [corners[0]]
    corners = array(corners).T
    corners = rotation @ corners + translation
    xc = corners[0]
    yc = corners[1]
    fill(xc, yc, color="#868e96", zorder=10)
    
    # Fixed Wheels
    wheel_left_xy_start = rotation @ [[-Rw], [-L/2]] + translation 
    wheel_left_xy_end = rotation @ [[Rw], [-L/2]] + translation
    plot([wheel_left_xy_start[0], wheel_left_xy_end[0]], [wheel_left_xy_start[1], wheel_left_xy_end[1]], color="black",linewidth=5, zorder=20)

    wheel_right_xy_start = rotation @ [[-Rw], [+L/2]] + translation
    wheel_right_xy_end = rotation @ [[Rw], [L/2]] + translation
    plot([wheel_right_xy_start[0], wheel_right_xy_end[0]], [wheel_right_xy_start[1], wheel_right_xy_end[1]], color="black", linewidth=5, zorder=20)

# %% [markdown]
# 🧩 Represent the wheelchair when $(x, y, \theta) = (0, 0, 0), (2, 2, \pi/2), (0, 4, \pi), (-2, 2, 3\pi/2)$.
#
# 🗝️ **Hint.** Use the following `draw_arena` function beforehand.

# %%
def draw_arena(xmin, xmax, ymin, ymax):
    wh_ratio = (xmax - xmin) / (ymax - ymin)
    figsize = fig_width, fig_height = 16, 16 / wh_ratio
    figure(figsize=figsize)
    axes = gca()
    axes.axis([xmin, xmax, ymin, ymax])
    axes.set_aspect(1)
    xticks(arange(xmin, xmax+1, 1))
    yticks(arange(ymin, ymax+1, 1))
    grid(True)

# %%
# 🔓
draw_arena(-5, 5, -1, 5)
draw_wheelchair(0, 0, 0)
draw_wheelchair(2, 2, pi/2)
draw_wheelchair(0, 4, pi)
draw_wheelchair(-2, 2, 3*pi/2)

# %% [markdown]
# ### Kinematic Modeling
#
# We assume that we can control the wheels angular velocities $\omega_l = \dot{\phi}_l$ and $\omega_r = \dot{\phi}_r$ (this is a *kinematic* model of the wheelchair).
# We also assume that the wheelchair fixed wheels roll without slipping.
#
# 🧩 Establish the differential equations that relate $\dot{x}$,
# $\dot{y}$ and $\dot{\theta}$ with $\omega_l$ and $\omega_r$.

# %% [markdown]
# 🔓
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} \\
# \end{array}
# $$

# %% [markdown]
# ### Analysis
#
# 🧩 Show that if $\omega_l$ and $\omega_r$ are continuously differentiable functions of $(x, y, \theta)$ (which includes the case of constant inputs), this system is well-posed.

# %% [markdown]
# 🔓 The vector field is continuously differentiable as a composition of continuously differentiable functions, thus the IVP is well-posed.

# %% [markdown]
# 🧩 Show that if $\omega_l$ and $\omega_r$ are constants, the maximal solution associated to any initial state is global. Is is still true of $\omega_l$ and $\omega_r$ are arbitrary continuously differentiable functions of $(x, y, \theta)$ ?

# %% [markdown]
# 🔓 When the inputs are constant, it's pretty easy to prove that the derivatives of $x$, $y$ and $\theta$ with respect to $t$ are uniformly bounded ; thus $x$, $y$ and $\theta$ are bounded on any bounded time interval and therefore no finite-time blowup may happen: the maximal solution is global.
#
# The situation is different with state-dependent inputs; for example with $\omega_r = - \omega_l = 0.5 (L/R_w)  \theta^2$, we end up with $\dot{\theta}(t) = \theta(t)^2$ which has a finite-time blowup for some initial values of $\theta$. Thus, the maximal solution may not be global.

# %% [markdown]
# ### Vector Field
#
# In the sequel, `omega` is a function that computes the input vector $\omega := (\omega_l, \omega_r)$ given the time $t$ and $(x, y, \theta)$ (thus, it may depend on the time and/or on the system state if needed). For example:

# %%
def omega(t, xytheta):
    omega_l = (1 - L/4) * pi / Rw
    omega_r = (1 + L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# 🧩 Implement a function `fun(t, xytheta)` that computes $(\dot{x}, \dot{y}, \dot{\theta})$ given the time $t$ and $(x,y,\theta)$ (and implicitly the inputs $\omega$ computed by the function `omega`).

# %%
# 🔓
def fun(t, xytheta):
    x, y, theta = xytheta
    omega_l, omega_r = omega(t, xytheta)
    dx = Rw * 0.5 * (omega_l + omega_r) * cos(theta)
    dy = Rw * 0.5 * (omega_l + omega_r) * sin(theta)
    dtheta = Rw * (omega_r - omega_l) / L
    return array([dx, dy, dtheta])

# %% [markdown]
# ### Simulation Setup
#
# 🧩 Simulate the wheelchair dynamics for 4 seconds when $(x_0, y_0, \theta_0)(t=0) = (0.0, 0.0, 0.0)$,
# and the wheels velocities are the constants $\omega_l = (1 - L/4)  \pi / R \mbox{ rad/s}$ and $\omega_r = (1 + L/4)  \pi / R_w \mbox{ rad/s}$.
# (Compute the dense outputs.)

# %%
# 🔓
r = solve_ivp(fun=fun, t_span =(0.0, 4.0), y0=[0.0, 0.0, 0.0], dense_output=True)

# %% [markdown]
# 🧩 Use the simulation results to draw the graphs of $x(t)$, $y(t)$ and $\theta(t)$.

# %%
# 🔓
t = linspace(0.0, 4.0, 1000)
x, y, theta = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, x, label="$x(t)$")
ax1.plot(t, y, label="$y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta, label=r"$\theta(t)$", color="C2")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 second.

# %%
# 🔓
t = linspace(0.0, 4.0, 4*2+1)
sol_t = r["sol"](t)
draw_arena(-4, 4, -1, 5)
for x, y, theta in sol_t.T:
    draw_wheelchair(x, y, theta)

# %% [markdown]
# 🧩 What should be the analytical expression of $x(t)$, $y(t)$ and $\theta(t)$?

# %% [markdown]
# $\theta(t) = 2 \pi / 4.0$, $x(t) = 2\sin(2\pi t / 4)$ and $y(t) = -2 \cos(2\pi t / 4)+2$.

# %% [markdown]
# 🧩 Do you experimental results match the theoretical results ? Draw the curves of the simulation error at time $t$ for $x$, $y$ and $\theta$.

# %%
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# 🧩 If needed, adjust the simulation parameters until this error is uniformly less than $2 \times 10^{-5}$ for every component of $(x, y, \theta)$.

# %%
r = solve_ivp(
    fun=fun, 
    t_span=(0.0, 4.0), 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-12, 
    dense_output=True
)
t = linspace(0.0, 4.0, 1000)
x_t, y_t, theta_t = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t , x_t - 2*sin(2*pi*t/4), label="$x(t)$ error")
ax1.plot(t , y_t + 2*cos(2*pi*t/4) - 2, label="$y(t)$ error")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta_t - 2*pi*t / 4.0, label=r"$\theta(t)$ error")
ax2.legend()
xlabel("time")
pass

# %% [markdown]
# Step 2 - Control Implementation
# ===============================

# %% [markdown]
# Time dependent inputs
# ---------------------

# %% [markdown]
# We are going to simulate the case of the chariot controlled by time-dependent angular velocities $\omega_l$ and $\omega_r$.
# We want a simulation lasting 5 seconds with the following inputs:
# $$
#     \omega_l(t) = \left\{
#        \begin{array}{rl}
#            (1 - L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 + L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$
# and
# $$
#     \omega_r(t) = \left\{
#        \begin{array}{rl}
#            (1 + L/4) \pi / R_w & \mbox{when $t \leq 1s$ or $t \geq 3$,} \\
#            (1 - L/4) \pi / R_w & \mbox{otherwise.}
#        \end{array}
#     \right.
# $$

# %% [markdown]
# ##### 🧩 Provide the new definition of `omega`

# %%
def omega(t, xytheta):
    omega_l = 0
    omega_r = 0
    if t <= 1 or t >= 3:
        omega_l = (1 - L/4) * pi / Rw
        omega_r = (1 + L/4) * pi / Rw
    else:
        omega_l = (1 + L/4) * pi / Rw
        omega_r = (1 - L/4) * pi / Rw
    return array([omega_l, omega_r])

# %% [markdown]
# ##### 🧩 Make a simulation of 4s of the robot with the previous input. Use the `rtol` and `atol` that used to guarantee a precision of $2 \times 10^{-5}$ and by using the `dense_output` option to evaluate the solution at timesteps that will be defined later.
#
# 🗝️ **Hint.** It is not necessary to define again the function `fun`. If the previous cell has been correctly validated, `fun` will use the new definition of `omega`.

# %%
import scipy.integrate as spi
solv = spi.solve_ivp(
    fun=fun, 
    t_span=[0.0, 4.0], 
    y0=[0.0, 0.0, 0.0], 
    rtol=1e-6, 
    atol=1e-12, 
    dense_output=True
)

# %% [markdown]
# 🧩 Use the simulation results to display the robot location every 0.5 seconds.

# %%
import numpy as np

t = np.linspace(0.0, 4.0, 9)
sol_t = solv.sol(t)
draw_arena(xmin=-2, xmax=10, ymin=-2, ymax=10)
for state in sol_t.T:
    x, y, theta = state
    draw_wheelchair(x, y, theta)

# %% [markdown]
# ## Analysis of the system at rest

# %% [markdown]
# ### Equilibrium

# %% [markdown]
# ##### 🧩 Show that for a suitable (constant) choice $\omega_e \in \mathbb{R}^2$ of the vector input $\omega$, the state $X_e = (x_e, y_e, \theta_e) = (0,0,0)$ is an equilibrium of the wheelchair kinematic model.

# %% [markdown]
# Ona $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} \\
# \end{array}
# $$
#
#
# pour $ (x,y,\theta)=(0,0,0)$ cherchons $\omega$ tel que,
# $$
# \dot{x} = 0, \dot{y} = 0, \dot{\theta} =0 \\
# $$
# ona $\omega=cte$ donc,
#
# $$
# \frac{\omega_l + \omega_r}{2}=0 \\
# \frac{\omega_l - \omega_r}{2}=0\\
# $$
# donc,
# $$
# \omega_e=(0,0)
# $$

# %% [markdown]
# ##### 🧩 Show that for any other $\omega_e$, the system has no equilibrium.

# %% [markdown]
# $X_e = (x_e, y_e, \theta_e) = (0,0,0)$ is an equilibrium of the wheelchair kinematic model.
# donc
#
# Ona
#
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta = 0 \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta = 0 \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} = 0 \\
# \end{array}
# $$
# Donc,
# $$
# \begin{array}{rcl}
# \dot{x}^2+\dot{y}^2 &=& (R_w  \frac{\omega_l + \omega_r}{2})^2 = 0 \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} = 0 \\
# \end{array}
# $$
# donc
# $$
# \frac{\omega_l + \omega_r}{2}=0 \\
# \frac{\omega_l - \omega_r}{2}=0\\
# $$
# donc,
#
# $\omega_e$ est unique

# %% [markdown]
# ##### 🧩 Conversely, if $\omega = \omega_e$, what are the other equilibria of the system?

# %% [markdown]
# Ona
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{\omega_l + \omega_r}{2} \cos \theta  \\
# \dot{y} &=& R_w  \frac{\omega_l + \omega_r}{2} \sin \theta  \\
# \dot{\theta} &=& R_w  \frac{\omega_r - \omega_l}{L} \\
# \end{array}
# $$
# pour $\omega = \omega_e$,
#
# $$
# \begin{array}{rcl}
# \dot{x} &=& R_w  \frac{0}{2} \cos \theta = 0 \\
# \dot{y} &=& R_w  \frac{0}{2} \sin \theta = 0 \\
# \dot{\theta} &=& R_w  \frac{0}{L} = 0 \\
# \end{array}
# $$
# Donc Tous les points  $X=(x(\omega_e,\theta),y(\omega_e,\theta),\theta)$ sont des équilibres

# %% [markdown]
# ### Linearized System Model
#
#
# Let $\omega = \omega_e$ and $X_e = (0,0,0)$. Let us introduce the the error variable $\Delta X = (\Delta x, \Delta y, \Delta \theta) = X - X_e$ and $\Delta \omega = \omega - \omega_e$.

# %% [markdown]
# ##### 🧩 Compute the corresponding linearized dynamics and put it in standard form: compute the matrices $A$ and $B$ (remember that $\omega = (\omega_l,\omega_r)$).

# %% [markdown]
# \begin{gathered}
# A=\left.\frac{\Delta \dot{X}}{\partial X}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{lll}
# \frac{\partial \dot{x}}{\partial x} & \frac{\partial \dot{x}}{\partial y} & \frac{\partial \dot{x}}{\partial \theta} \\
# \frac{\partial \dot{y}}{\partial x} & \frac{\partial y}{\partial y} & \frac{\partial \dot{y}}{\partial \theta} \\
# \frac{\partial \dot{\theta}}{\partial x} & \frac{\partial \theta}{\partial y} & \frac{\partial \dot{\theta}}{\partial \theta}
# \end{array}\right]=\left[\begin{array}{lll}
# 0 & 0 & -R_w \frac{\omega_l+\omega_r}{2} \sin \theta \\
# 0 & 0 & R_w \frac{\omega_l+\omega_r}{2} \cos \theta \\
# 0 & 0 & 0
# \end{array}\right] \\
# B=\left.\frac{\Delta \dot{X}}{\partial \omega}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{ll}
# \frac{\partial \dot{x}}{\partial \omega_l} & \frac{\partial \dot{x}}{\partial \omega_r} \\
# \frac{\partial y}{\partial \omega_l} & \frac{\partial y}{\partial \omega_r} \\
# \frac{\partial \theta}{\partial \omega_l} & \frac{\partial \theta}{\partial \omega_r}
# \end{array}\right]=\left[\begin{array}{ll}
# \frac{R_w}{2} \cos \theta & \frac{R_w}{2} \cos \theta \\
# \frac{R_w}{2} \sin \theta & \frac{R_w}{2} \sin \theta \\
# \frac{-R_w}{L} & \frac{R_w}{L}
# \end{array}\right]
# \end{gathered}\\
# Pour $\omega = \omega_e$ et $X_e = (0,0,0)$,\\
# \begin{gathered}
# A=\left.\frac{\Delta \dot{X}}{\partial X}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{lll}
# \frac{\partial \dot{x}}{\partial x} & \frac{\partial \dot{x}}{\partial y} & \frac{\partial \dot{x}}{\partial \theta} \\
# \frac{\partial \dot{y}}{\partial x} & \frac{\partial y}{\partial y} & \frac{\partial \dot{y}}{\partial \theta} \\
# \frac{\partial \dot{\theta}}{\partial x} & \frac{\partial \theta}{\partial y} & \frac{\partial \dot{\theta}}{\partial \theta}
# \end{array}\right]=\left[\begin{array}{lll}
# 0 & 0 & 0 \\
# 0 & 0 & 0 \\
# 0 & 0 & 0
# \end{array}\right] \\
# B=\left.\frac{\Delta \dot{X}}{\partial \omega}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{ll}
# \frac{\partial \dot{x}}{\partial \omega_l} & \frac{\partial \dot{x}}{\partial \omega_r} \\
# \frac{\partial y}{\partial \omega_l} & \frac{\partial y}{\partial \omega_r} \\
# \frac{\partial \theta}{\partial \omega_l} & \frac{\partial \theta}{\partial \omega_r}
# \end{array}\right]=\left[\begin{array}{ll}
# \frac{R_w}{2}  & \frac{R_w}{2}  \\
# 0 & 0 \\
# \frac{-R_w}{L} & \frac{R_w}{L}
# \end{array}\right]
# \end{gathered}

# %% [markdown]
# ### Stability of the linearized system

# %% [markdown]
# ##### 🧩 Is the linearized system asymptotically stable around $(0,0,0)$ when $\Delta \omega = (0,0)$ ?

# %% [markdown]
# Dans ce cas,
# $$
# \Delta \dot{X} =  A \Delta X
# $$
#
# la seule valeur propre de A c'est 0 ( la partie réelle n'est pas strictement négative). Donc,
# le système linéarisé n'est pas asymptotiquement stable autour de $(0,0,0)$ lorsque $\Delta \omega = (0,0)$,

# %% [markdown]
# ##### 🧩 Is the original system asymptotically stable ? Or even (locally) attractive ?

# %% [markdown]
# Pour $\omega=\omega_e$, le système ne bouge pas. Si $X\left(t_0\right)=X_0$, alors $\forall t>0, X(t)=X_0$.
# Ainsi, si $X_0 \neq(0,0,0), X(t)$ ne peut pas converger vers l'origine : le système original n'est pas donc attractif.
# et par conséquent Le système original n'est pas asymptotiquement stable.

# %% [markdown]
# ### Controllability of the linearized system

# %% [markdown]
# In this section, we consider only the linearized system defined by the matrices $A$ and $B$ computed previously:
#
# $$
# \frac{\Delta X}{dt} = A \Delta X + B\Delta u
# $$

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(-2,0,0)$ and ends at origin after some time?

# %% [markdown]
# Dans notre cas,
# $$
# \frac{\Delta X}{dt} =  B\Delta u =\left[\begin{array}{ll}
# \frac{R_w}{2} (\omega_l+\omega_r)  \\
# 0  \\
# \frac{-R_w}{L}(\omega_r-\omega_l)
# \end{array}\right]
# $$
# et
# $$
# \frac{\Delta X}{dt} =  \left[\begin{array}{ll}
# \dot{x}   \\
# 0  \\
# 0
# \end{array}\right]
# $$
# Pour $\omega_r=\omega_l$ et $\dot{x}=\frac{R_w}{2} (\omega_l+\omega_r) $ on peut partir de l'état $X_0=(-2,0,0)$ et  aller à l'origine

# %% [markdown]
# ##### 🧩 Is there an admissible trajectory that start with the state $X_0=(0,2,0)$ and ends at origin after some time?

# %% [markdown]
# Dans notre cas,
# $$
# \frac{\Delta X}{dt} =  B\Delta u =\left[\begin{array}{ll}
# \frac{R_w}{2} (\omega_l+\omega_r)  \\
# 0  \\
# \frac{-R_w}{L}(\omega_r-\omega_l)
# \end{array}\right]
# $$
# et
# $$
# \frac{\Delta X}{dt} =  \left[\begin{array}{ll}
# 0   \\
# \dot{y}  \\
# 0
# \end{array}\right]
# $$
# Pour $\omega_r=\omega_l$ et $\omega_r=-\omega_l$, on ne peut jamais donc arriver à l'origine à partir de $X_0$

# %% [markdown]
# ##### 🧩 Is the linearized system controllable?

# %% [markdown]
# Dans ce cas, la matrice de contrôlabilité $\mathcal{C}$ se réduit simplement à :
#
# $\mathcal{C} = \begin{bmatrix} B & 0 & \cdots & 0 \end{bmatrix}$
#
# En utilisant la matrice $B$ donnée dans la question, on obtient :
#
# le rang de la matrice C est inférieur de 3, donc le système n'est pas contrôlable

# %% [markdown]
# ## Control on a straight line
#
# ### Admissible trajectories

# %% [markdown]
# Let $x_R(t) = v t$ and $y_R(t) = 0$ where $v \in \mathbb{R}$ and $v \neq 0$.

# %% [markdown]
# ##### 🧩 Determine the set of trajectories $X_R(t) = (x_R(t), y_R(t), \theta_R(t))$ which are admissible and compute the corresponding reference control $\omega_{R}(t)$.

# %% [markdown]
# $ \dot{y_R} = R_w  \frac{\omega_l + \omega_r}{2} \sin \theta = 0 $,
# $ y_R(t) = 0 \\$
#
# Donc, $ \dot{y}=0$ donc, $ \sin \theta_R = 0$ car $\frac{\omega_l + \omega_r}{2}\ne 0$ ($\dot{x} \ne 0 $)
#
# Donc $ \theta_R \in (k \pi, k \in N)$
# et par conséquent $ \omega_l = \omega_r = \omega $ ( $\dot{\theta_R} = 0 $
# Dans ce cas,
#
# $ \dot{x_R} = \epsilon R_w \omega  = vt $
#
# Donc $\omega = \epsilon \frac{vt}{R_w}$
#
# avec $\epsilon^2=1$
#
# C/C
#
# L'ensemble des trajectoires c'est ($X_R(t) = (vt, 0, k\pi)$, $ v \in R^*$, $k \in N$  )

# %% [markdown]
# ### Linearized system

# %% [markdown]
# Let $\Delta X(t) = X(t) - X_R(t)$ and $\Delta \omega(t) = \omega(t) - \omega_R(t)$.

# %% [markdown]
# ##### 🧩 Compute the linearized dynamics of the system for the class of trajectory "moving forward".

# %% [markdown]
# **Answer:**
#
# \begin{gathered}
# A=\left.\frac{\Delta \dot{X}}{\partial X}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{lll}
# \frac{\partial \dot{x}}{\partial x} & \frac{\partial \dot{x}}{\partial y} & \frac{\partial \dot{x}}{\partial \theta} \\
# \frac{\partial \dot{y}}{\partial x} & \frac{\partial y}{\partial y} & \frac{\partial \dot{y}}{\partial \theta} \\
# \frac{\partial \dot{\theta}}{\partial x} & \frac{\partial \theta}{\partial y} & \frac{\partial \dot{\theta}}{\partial \theta}
# \end{array}\right]=\left[\begin{array}{lll}
# 0 & 0 & 0 \\
# 0 & 0 & v \\
# 0 & 0 & 0
# \end{array}\right] \\
# B=\left.\frac{\Delta \dot{X}}{\partial \omega}\right|_{X=X_e, \omega=\omega_e}=\left[\begin{array}{ll}
# \frac{\partial \dot{x}}{\partial \omega_l} & \frac{\partial \dot{x}}{\partial \omega_r} \\
# \frac{\partial y}{\partial \omega_l} & \frac{\partial y}{\partial \omega_r} \\
# \frac{\partial \theta}{\partial \omega_l} & \frac{\partial \theta}{\partial \omega_r}
# \end{array}\right]=\left[\begin{array}{ll}
# \frac{R_w}{2}  & \frac{R_w}{2}  \\
# 0 & 0 \\
# \frac{-R_w}{L} & \frac{R_w}{L}
# \end{array}\right]
# \end{gathered}

# %% [markdown]
# ##### 🧩 Is the system asymptotically stable, with $\Delta\omega(t)=0$?

# %% [markdown]
# Le système n'est pas asymptotiquement stable autour de $(0,0,0)$ et lorsque $w=w_e$. Cela est dû au fait que les valeurs propres de $\mathbf{A}$ sont toutes nulles.

# %% [markdown]
# ##### 🧩 Is the system attractive, with $\Delta\omega(t)=0$?

# %% [markdown]
# NON, car l'erreur Δ𝑦=cte

# %% [markdown]
# ##### 🧩 Show that the linearized system is controllable.

# %% [markdown]
# La matrice de contrôlabilité est donnée par:
#
# $$
# \mathcal{C}=\left[\begin{array}{lll}
# B & A B & A^2 B
# \end{array}\right]=\left[\begin{array}{cccccc}
# \frac{R_w}{2} & \frac{R_w}{2} & 0 & 0  \\
# 0 & 0 & -\frac{R_w v}{2} & \frac{R_w v}{2}  \\
# -\frac{R_w}{2} & \frac{R_w}{2} & 0 & 0
# \end{array}\right]
# $$
# donc le système est contrôlable

# %% [markdown]
# ### Linearized system implementation

# %% [markdown]
# In the sequel, we will use $v=4.8 \mbox{ km/h}$.

# %% [markdown]
# ##### 🧩 Implement and print the matrices $A$ and $B$

# %%
import numpy as np

v = 4.8/3.6  # m/s


A = np.array([[0,0,0],[0,0,v],[0,0,0]])

B = np.array([[Rw/2,Rw/2],[0,0],[-Rw/L,Rw/L]])

# %% [markdown]
# The linear model has to be fed with some $\Delta\omega$ input. Like for the nonlinear system, we define a function $\Delta\omega(t,\Delta_X)$ that computes the input of the linearized system. For example, if we do not want any correction to the reference input, we set:

# %%
def deltaOmega(t, deltaX):
    return np.array([0, 0])

# %% [markdown]
# ##### 🧩 Using this function `deltaOmega`, define a function `lin_fun` that computes $d{\Delta X}/dt$ given the arguments `t` and `deltaX`$.

# %%
def lin_fun(t, deltaX):
    DeltaX = np.dot(A, deltaX)
    DeltaO = np.dot(B, deltaOmega(t, deltaX))
    return DeltaX + DeltaO

# %% [markdown]
# ### Controller Design on the linearized system

# %% [markdown]
# ##### 🧩 Implement a process that computes a gain matrix $K$ that places the poles of the linearized system at some arbitrary location.
#
# For this question, we will chose 3 real poles close to -0.5.
#
# Then, print the poles of the closed-loop system
#
# $$
# \frac{d\Delta X}{dt}= A \Delta X + B\Delta\omega
# \; \mbox{ with } \;
# \Delta\omega = -K \Delta X.
# $$

# %%
poles = np.array([-0.53, -0.49, -0.52])

K = place_poles(A, B, poles).gain_matrix
print(K)

closed_loop = eigvals(A - B@K)
print( real(closed_loop))
# Out:
# [[ 1.73333329 -0.16160477 -0.84820242]
#  [ 1.73333338  0.16302023  0.85179758]]
# [-0.52 -0.53 -0.49]

# %% [markdown]
# ##### 🧩 Simulate the linearized system during 20s, with the initial condition $\Delta X(0) = (0,2,0)$.

# %%
def deltaOmega(t,deltaX):
    return -K@deltaX

dur = 20
r = solve_ivp(fun=lin_fun,t_span=[0,dur],y0=[0,2,0],dense_output=True, rtol=1e-6, atol=1e-12)

# %% [markdown]
# 🧩 Plot the values of $\Delta x(t)$, $\Delta y(t)$ and $\Delta\theta(t)$ (**plot $\Delta\theta(t)$ in degrees**)

# %%
t = linspace(0.0,dur, 500)

x, y, theta = r["sol"](t)
fig=figure(figsize=(15, 15))
ax1, ax2 = fig.subplots(2, 1, sharex=True)
ax1.grid(True)
ax1.plot(t, x, label="$x(t)$")
ax1.plot(t, y, label="$y(t)$")
ax1.legend()
ax2.grid(True)
ax2.plot(t, theta*180/pi, label=r"$\theta(t)$")
ax2.legend()

# %% [markdown]
# ##### 🧩 Why is it important to check that $\Delta\theta(t)$ stays small ?

# %% [markdown]
# Car une légère variation dans une coordonnée peut avoir un impact significatif sur la trajectoire au fil du temps.

# %% [markdown]
# ##### 🧩 Compute the corresponding values of $\Delta\omega_l,\Delta\omega_r$ and store them in the Python variables `dOmega_l`, `dOmega_r`

# %%
X = r["sol"](t)

dOmega = -K@X

dOmega_l = dOmega[0]
dOmega_r = dOmega[1]

print(dOmega_l,dOmega_r)
# Out:
# [ 3.23209543e-01  3.10196718e-01  2.97578362e-01  2.85343833e-01
#   2.73482757e-01  2.61985018e-01  2.50840761e-01  2.40040389e-01
#   2.29574544e-01  2.19434098e-01  2.09610157e-01  2.00094051e-01
#   1.90877353e-01  1.81951841e-01  1.73309498e-01  1.64942507e-01
#   1.56843254e-01  1.49004316e-01  1.41418480e-01  1.34078720e-01
#   1.26978179e-01  1.20110172e-01  1.13468184e-01  1.07045872e-01
#   1.00837055e-01  9.48357325e-02  8.90360556e-02  8.34323179e-02
#   7.80189560e-02  7.27905500e-02  6.77418228e-02  6.28676327e-02
#   5.81629907e-02  5.36230403e-02  4.92430434e-02  4.50183803e-02
#   4.09445497e-02  3.70171683e-02  3.32319701e-02  2.95848014e-02
#   2.60716376e-02  2.26885562e-02  1.94317312e-02  1.62974332e-02
#   1.32820296e-02  1.03819846e-02  7.59385793e-03  4.91430020e-03
#   2.34006971e-03 -1.31990974e-04 -2.50496118e-03 -4.78184208e-03
#  -6.96555675e-03 -9.05895011e-03 -1.10647889e-02 -1.29857665e-02
#  -1.48244933e-02 -1.65835009e-02 -1.82652583e-02 -1.98721718e-02
#  -2.14065856e-02 -2.28707813e-02 -2.42669778e-02 -2.55973320e-02
#  -2.68639437e-02 -2.80688411e-02 -2.92139945e-02 -3.03013250e-02
#  -3.13327042e-02 -3.23099542e-02 -3.32348480e-02 -3.41091091e-02
#  -3.49344117e-02 -3.57123848e-02 -3.64446020e-02 -3.71325879e-02
#  -3.77778285e-02 -3.83817715e-02 -3.89458258e-02 -3.94713619e-02
#  -3.99597117e-02 -4.04121687e-02 -4.08299889e-02 -4.12143916e-02
#  -4.15665500e-02 -4.18876060e-02 -4.21786716e-02 -4.24408293e-02
#  -4.26751319e-02 -4.28826023e-02 -4.30642339e-02 -4.32209902e-02
#  -4.33538069e-02 -4.34635892e-02 -4.35512076e-02 -4.36175096e-02
#  -4.36633199e-02 -4.36894407e-02 -4.36966517e-02 -4.36857098e-02
#  -4.36573495e-02 -4.36122827e-02 -4.35511993e-02 -4.34747680e-02
#  -4.33836288e-02 -4.32784037e-02 -4.31596978e-02 -4.30280991e-02
#  -4.28841788e-02 -4.27284911e-02 -4.25615733e-02 -4.23839458e-02
#  -4.21961120e-02 -4.19985606e-02 -4.17917593e-02 -4.15761585e-02
#  -4.13521959e-02 -4.11202966e-02 -4.08808734e-02 -4.06343265e-02
#  -4.03810438e-02 -4.01214004e-02 -3.98557593e-02 -3.95844707e-02
#  -3.93078743e-02 -3.90262933e-02 -3.87400387e-02 -3.84494123e-02
#  -3.81547069e-02 -3.78562065e-02 -3.75541857e-02 -3.72489104e-02
#  -3.69406372e-02 -3.66296138e-02 -3.63160789e-02 -3.60002631e-02
#  -3.56823864e-02 -3.53626578e-02 -3.50412800e-02 -3.47184492e-02
#  -3.43943551e-02 -3.40691811e-02 -3.37431043e-02 -3.34162953e-02
#  -3.30889183e-02 -3.27611311e-02 -3.24330852e-02 -3.21049267e-02
#  -3.17767925e-02 -3.14488131e-02 -3.11211149e-02 -3.07938196e-02
#  -3.04670448e-02 -3.01409035e-02 -2.98155043e-02 -2.94909513e-02
#  -2.91673445e-02 -2.88447793e-02 -2.85233465e-02 -2.82031337e-02
#  -2.78842216e-02 -2.75666866e-02 -2.72506017e-02 -2.69360373e-02
#  -2.66230608e-02 -2.63117367e-02 -2.60021265e-02 -2.56942887e-02
#  -2.53882789e-02 -2.50841499e-02 -2.47819515e-02 -2.44817306e-02
#  -2.41835314e-02 -2.38873931e-02 -2.35933528e-02 -2.33014457e-02
#  -2.30117052e-02 -2.27241628e-02 -2.24388481e-02 -2.21557888e-02
#  -2.18750109e-02 -2.15965384e-02 -2.13203933e-02 -2.10465961e-02
#  -2.07751652e-02 -2.05061173e-02 -2.02394659e-02 -1.99752226e-02
#  -1.97133984e-02 -1.94540028e-02 -1.91970444e-02 -1.89425306e-02
#  -1.86904677e-02 -1.84408609e-02 -1.81937144e-02 -1.79490311e-02
#  -1.77068129e-02 -1.74670605e-02 -1.72297738e-02 -1.69949511e-02
#  -1.67625886e-02 -1.65326819e-02 -1.63052260e-02 -1.60802155e-02
#  -1.58576442e-02 -1.56375053e-02 -1.54197915e-02 -1.52044950e-02
#  -1.49916072e-02 -1.47811191e-02 -1.45730210e-02 -1.43673027e-02
#  -1.41639532e-02 -1.39629613e-02 -1.37643141e-02 -1.35679981e-02
#  -1.33739996e-02 -1.31823049e-02 -1.29928996e-02 -1.28057695e-02
#  -1.26208999e-02 -1.24382760e-02 -1.22578825e-02 -1.20797042e-02
#  -1.19037254e-02 -1.17299303e-02 -1.15583027e-02 -1.13888265e-02
#  -1.12214849e-02 -1.10562607e-02 -1.08931361e-02 -1.07320931e-02
#  -1.05731139e-02 -1.04161806e-02 -1.02612752e-02 -1.01083797e-02
#  -9.95747613e-03 -9.80854649e-03 -9.66157269e-03 -9.51653664e-03
#  -9.37342020e-03 -9.23220525e-03 -9.09287359e-03 -8.95540701e-03
#  -8.81978729e-03 -8.68599590e-03 -8.55401393e-03 -8.42382249e-03
#  -8.29540281e-03 -8.16873619e-03 -8.04380402e-03 -7.92058780e-03
#  -7.79906910e-03 -7.67922959e-03 -7.56105103e-03 -7.44451526e-03
#  -7.32960423e-03 -7.21629997e-03 -7.10458459e-03 -6.99444030e-03
#  -6.88584941e-03 -6.77879430e-03 -6.67325738e-03 -6.56922074e-03
#  -6.46666659e-03 -6.36557728e-03 -6.26593533e-03 -6.16772335e-03
#  -6.07092413e-03 -5.97552058e-03 -5.88149576e-03 -5.78883286e-03
#  -5.69751522e-03 -5.60752631e-03 -5.51884974e-03 -5.43146927e-03
#  -5.34536879e-03 -5.26053233e-03 -5.17694406e-03 -5.09458829e-03
#  -5.01344947e-03 -4.93351181e-03 -4.85475974e-03 -4.77717789e-03
#  -4.70075103e-03 -4.62546410e-03 -4.55130219e-03 -4.47825050e-03
#  -4.40629441e-03 -4.33541945e-03 -4.26561127e-03 -4.19685570e-03
#  -4.12913868e-03 -4.06244634e-03 -3.99676493e-03 -3.93208084e-03
#  -3.86838063e-03 -3.80565100e-03 -3.74387868e-03 -3.68305048e-03
#  -3.62315341e-03 -3.56417467e-03 -3.50610155e-03 -3.44892151e-03
#  -3.39262214e-03 -3.33719117e-03 -3.28261646e-03 -3.22888603e-03
#  -3.17598802e-03 -3.12391070e-03 -3.07264251e-03 -3.02217199e-03
#  -2.97248786e-03 -2.92357895e-03 -2.87543420e-03 -2.82804263e-03
#  -2.78139343e-03 -2.73547595e-03 -2.69027965e-03 -2.64579412e-03
#  -2.60200906e-03 -2.55891432e-03 -2.51649985e-03 -2.47475574e-03
#  -2.43367219e-03 -2.39323953e-03 -2.35344822e-03 -2.31428883e-03
#  -2.27575208e-03 -2.23782877e-03 -2.20050983e-03 -2.16378627e-03
#  -2.12764928e-03 -2.09209015e-03 -2.05710026e-03 -2.02267113e-03
#  -1.98879436e-03 -1.95546168e-03 -1.92266490e-03 -1.89039596e-03
#  -1.85864691e-03 -1.82740989e-03 -1.79667715e-03 -1.76644107e-03
#  -1.73669410e-03 -1.70742881e-03 -1.67863784e-03 -1.65031399e-03
#  -1.62245014e-03 -1.59503926e-03 -1.56807441e-03 -1.54154875e-03
#  -1.51545553e-03 -1.48978809e-03 -1.46453985e-03 -1.43970434e-03
#  -1.41527517e-03 -1.39124605e-03 -1.36761078e-03 -1.34436323e-03
#  -1.32149737e-03 -1.29900725e-03 -1.27688703e-03 -1.25513096e-03
#  -1.23373334e-03 -1.21268857e-03 -1.19199112e-03 -1.17163552e-03
#  -1.15161641e-03 -1.13192847e-03 -1.11256650e-03 -1.09352533e-03
#  -1.07479989e-03 -1.05638520e-03 -1.03827633e-03 -1.02046841e-03
#  -1.00295669e-03 -9.85736477e-04 -9.68803138e-04 -9.52152110e-04
#  -9.35778892e-04 -9.19679047e-04 -9.03848200e-04 -8.88282044e-04
#  -8.72976332e-04 -8.57926883e-04 -8.43129578e-04 -8.28580365e-04
#  -8.14275249e-04 -8.00210287e-04 -7.86381620e-04 -7.72785450e-04
#  -7.59418029e-04 -7.46275665e-04 -7.33354715e-04 -7.20651591e-04
#  -7.08162757e-04 -6.95884729e-04 -6.83814079e-04 -6.71947426e-04
#  -6.60281447e-04 -6.48812869e-04 -6.37538471e-04 -6.26455071e-04
#  -6.15559558e-04 -6.04848873e-04 -5.94319997e-04 -5.83969955e-04
#  -5.73795818e-04 -5.63794696e-04 -5.53963744e-04 -5.44300162e-04
#  -5.34801191e-04 -5.25464115e-04 -5.16286262e-04 -5.07265003e-04
#  -4.98397751e-04 -4.89681952e-04 -4.81115112e-04 -4.72694774e-04
#  -4.64418519e-04 -4.56283962e-04 -4.48288753e-04 -4.40430579e-04
#  -4.32707159e-04 -4.25116251e-04 -4.17655644e-04 -4.10323166e-04
#  -4.03116678e-04 -3.96034077e-04 -3.89073292e-04 -3.82232284e-04
#  -3.75509060e-04 -3.68901657e-04 -3.62408142e-04 -3.56026609e-04
#  -3.49755183e-04 -3.43592016e-04 -3.37535288e-04 -3.31583209e-04
#  -3.25734017e-04 -3.19985978e-04 -3.14337388e-04 -3.08786570e-04
#  -3.03331873e-04 -2.97971674e-04 -2.92704387e-04 -2.87528449e-04
#  -2.82442320e-04 -2.77444483e-04 -2.72533445e-04 -2.67707737e-04
#  -2.62965909e-04 -2.58306539e-04 -2.53728225e-04 -2.49229589e-04
#  -2.44809277e-04 -2.40465957e-04 -2.36198315e-04 -2.32005067e-04
#  -2.27884953e-04 -2.23836732e-04 -2.19859180e-04 -2.15951096e-04
#  -2.12111292e-04 -2.08338602e-04 -2.04631880e-04 -2.00989994e-04
#  -1.97411836e-04 -1.93896311e-04 -1.90442348e-04 -1.87048891e-04
#  -1.83714900e-04 -1.80439359e-04 -1.77221271e-04 -1.74059653e-04
#  -1.70953536e-04 -1.67901969e-04 -1.64904011e-04 -1.61958742e-04
#  -1.59065251e-04 -1.56222648e-04 -1.53430052e-04 -1.50686601e-04
#  -1.47991447e-04 -1.45343755e-04 -1.42742706e-04 -1.40187497e-04
#  -1.37677342e-04 -1.35211462e-04 -1.32789094e-04 -1.30409485e-04
#  -1.28071894e-04 -1.25775592e-04 -1.23519862e-04 -1.21304001e-04
#  -1.19127316e-04 -1.16989125e-04 -1.14888762e-04 -1.12825570e-04] [-3.26040456e-01 -3.12914239e-01 -3.00185910e-01 -2.87844736e-01
#  -2.75880253e-01 -2.64282258e-01 -2.53040810e-01 -2.42146232e-01
#  -2.31589082e-01 -2.21360154e-01 -2.11450479e-01 -2.01851311e-01
#  -1.92554150e-01 -1.83550703e-01 -1.74832884e-01 -1.66392809e-01
#  -1.58222797e-01 -1.50315363e-01 -1.42663230e-01 -1.35259311e-01
#  -1.28096690e-01 -1.21168625e-01 -1.14468544e-01 -1.07990049e-01
#  -1.01726906e-01 -9.56730627e-02 -8.98226195e-02 -8.41698204e-02
#  -7.87090540e-02 -7.34348535e-02 -6.83418961e-02 -6.34249956e-02
#  -5.86791197e-02 -5.40993699e-02 -4.96809672e-02 -4.54192518e-02
#  -4.13096832e-02 -3.73478404e-02 -3.35294203e-02 -2.98502333e-02
#  -2.63062198e-02 -2.28934233e-02 -1.96079846e-02 -1.64461421e-02
#  -1.34042316e-02 -1.04786866e-02 -7.66603697e-03 -4.96290430e-03
#  -2.36601873e-03  1.27804579e-04  2.52167169e-03  4.81860985e-03
#   7.02156749e-03  9.13341426e-03  1.11569410e-02  1.30948644e-02
#   1.49498175e-02  1.67243540e-02  1.84209643e-02  2.00420758e-02
#   2.15900528e-02  2.30671969e-02  2.44757464e-02  2.58178768e-02
#   2.70957062e-02  2.83112805e-02  2.94665872e-02  3.05635640e-02
#   3.16040988e-02  3.25900298e-02  3.35231451e-02  3.44051835e-02
#   3.52378336e-02  3.60227388e-02  3.67614862e-02  3.74556138e-02
#   3.81066206e-02  3.87159668e-02  3.92850736e-02  3.98153236e-02
#   4.03080603e-02  4.07645884e-02  4.11861749e-02  4.15740497e-02
#   4.19293963e-02  4.22533665e-02  4.25470822e-02  4.28116352e-02
#   4.30480875e-02  4.32574710e-02  4.34407877e-02  4.35990097e-02
#   4.37330807e-02  4.38439139e-02  4.39323875e-02  4.39993562e-02
#   4.40456521e-02  4.40720845e-02  4.40794396e-02  4.40684812e-02
#   4.40399502e-02  4.39945646e-02  4.39330206e-02  4.38559925e-02
#   4.37641261e-02  4.36580487e-02  4.35383708e-02  4.34056856e-02
#   4.32605692e-02  4.31035807e-02  4.29352622e-02  4.27561387e-02
#   4.25667179e-02  4.23674927e-02  4.21589352e-02  4.19414995e-02
#   4.17156272e-02  4.14817473e-02  4.12402761e-02  4.09916174e-02
#   4.07361623e-02  4.04742895e-02  4.02063650e-02  3.99327422e-02
#   3.96537637e-02  3.93697556e-02  3.90810316e-02  3.87878962e-02
#   3.84906449e-02  3.81895640e-02  3.78849306e-02  3.75770129e-02
#   3.72660699e-02  3.69523515e-02  3.66360983e-02  3.63175431e-02
#   3.59969077e-02  3.56744033e-02  3.53502340e-02  3.50245979e-02
#   3.46976864e-02  3.43696845e-02  3.40407709e-02  3.37111177e-02
#   3.33808905e-02  3.30502486e-02  3.27193447e-02  3.23883264e-02
#   3.20573316e-02  3.17264922e-02  3.13959355e-02  3.10657845e-02
#   3.07361577e-02  3.04071690e-02  3.00789282e-02  2.97515403e-02
#   2.94251060e-02  2.90997217e-02  2.87754791e-02  2.84524664e-02
#   2.81307652e-02  2.78104523e-02  2.74916017e-02  2.71742843e-02
#   2.68585681e-02  2.65445181e-02  2.62321963e-02  2.59216620e-02
#   2.56129711e-02  2.53061770e-02  2.50013298e-02  2.46984769e-02
#   2.43976629e-02  2.40989274e-02  2.38023078e-02  2.35078396e-02
#   2.32155566e-02  2.29254905e-02  2.26376711e-02  2.23521266e-02
#   2.20688829e-02  2.17879645e-02  2.15093936e-02  2.12331906e-02
#   2.09593744e-02  2.06879618e-02  2.04189663e-02  2.01523997e-02
#   1.98882731e-02  1.96265960e-02  1.93673772e-02  1.91106242e-02
#   1.88563433e-02  1.86045397e-02  1.83552177e-02  1.81083803e-02
#   1.78640293e-02  1.76221656e-02  1.73827889e-02  1.71458976e-02
#   1.69114878e-02  1.66795553e-02  1.64500948e-02  1.62231010e-02
#   1.59985675e-02  1.57764876e-02  1.55568540e-02  1.53396587e-02
#   1.51248930e-02  1.49125480e-02  1.47026137e-02  1.44950800e-02
#   1.42899358e-02  1.40871697e-02  1.38867687e-02  1.36887193e-02
#   1.34930077e-02  1.32996199e-02  1.31085416e-02  1.29197583e-02
#   1.27332552e-02  1.25490174e-02  1.23670296e-02  1.21872763e-02
#   1.20097418e-02  1.18344101e-02  1.16612649e-02  1.14902898e-02
#   1.13214681e-02  1.11547823e-02  1.09902144e-02  1.08277464e-02
#   1.06673603e-02  1.05090380e-02  1.03527613e-02  1.01985122e-02
#   1.00462726e-02  9.89602409e-03  9.74774861e-03  9.60142788e-03
#   9.45704362e-03  9.31457752e-03  9.17401124e-03  9.03532643e-03
#   8.89850469e-03  8.76352734e-03  8.63037529e-03  8.49902952e-03
#   8.36947107e-03  8.24168108e-03  8.11564080e-03  7.99133155e-03
#   7.86873475e-03  7.74783191e-03  7.62860463e-03  7.51103460e-03
#   7.39510360e-03  7.28079350e-03  7.16808628e-03  7.05696398e-03
#   6.94740876e-03  6.83940284e-03  6.73292848e-03  6.62796762e-03
#   6.52450231e-03  6.42251476e-03  6.32198731e-03  6.22290245e-03
#   6.12524280e-03  6.02899113e-03  5.93413034e-03  5.84064349e-03
#   5.74851377e-03  5.65772450e-03  5.56825915e-03  5.48010133e-03
#   5.39323481e-03  5.30764347e-03  5.22331134e-03  5.14022259e-03
#   5.05836154e-03  4.97771227e-03  4.89825905e-03  4.81998639e-03
#   4.74287894e-03  4.66692149e-03  4.59209899e-03  4.51839654e-03
#   4.44579938e-03  4.37429291e-03  4.30386265e-03  4.23449431e-03
#   4.16617372e-03  4.09888687e-03  4.03261989e-03  3.96735907e-03
#   3.90309083e-03  3.83980176e-03  3.77747849e-03  3.71610768e-03
#   3.65567627e-03  3.59617130e-03  3.53757999e-03  3.47988967e-03
#   3.42308782e-03  3.36716207e-03  3.31210017e-03  3.25789003e-03
#   3.20451969e-03  3.15197733e-03  3.10025126e-03  3.04932995e-03
#   2.99920199e-03  2.94985613e-03  2.90128121e-03  2.85346616e-03
#   2.80640007e-03  2.76007219e-03  2.71447189e-03  2.66958867e-03
#   2.62541215e-03  2.58193208e-03  2.53913832e-03  2.49702086e-03
#   2.45556984e-03  2.41477550e-03  2.37462820e-03  2.33511844e-03
#   2.29623684e-03  2.25797416e-03  2.22032120e-03  2.18326893e-03
#   2.14680843e-03  2.11093094e-03  2.07562775e-03  2.04089031e-03
#   2.00671015e-03  1.97307891e-03  1.93998834e-03  1.90743032e-03
#   1.87539681e-03  1.84387988e-03  1.81287173e-03  1.78236466e-03
#   1.75235106e-03  1.72282342e-03  1.69377434e-03  1.66519653e-03
#   1.63708282e-03  1.60942611e-03  1.58221942e-03  1.55545582e-03
#   1.52912852e-03  1.50323080e-03  1.47775601e-03  1.45269764e-03
#   1.42804923e-03  1.40380443e-03  1.37995700e-03  1.35650075e-03
#   1.33342959e-03  1.31073753e-03  1.28841867e-03  1.26646720e-03
#   1.24487739e-03  1.22364358e-03  1.20276018e-03  1.18222169e-03
#   1.16202269e-03  1.14215783e-03  1.12262184e-03  1.10340952e-03
#   1.08451576e-03  1.06593551e-03  1.04766382e-03  1.02969577e-03
#   1.01202657e-03  9.94651479e-04  9.77565828e-04  9.60765011e-04
#   9.44244489e-04  9.27999785e-04  9.12026486e-04  8.96320244e-04
#   8.80876777e-04  8.65691865e-04  8.50761354e-04  8.36081154e-04
#   8.21647236e-04  8.07455622e-04  7.93502419e-04  7.79783793e-04
#   7.66295966e-04  7.53035209e-04  7.39997851e-04  7.27180269e-04
#   7.14578897e-04  7.02190220e-04  6.90010778e-04  6.78037162e-04
#   6.66266018e-04  6.54694044e-04  6.43317990e-04  6.32134647e-04
#   6.21140876e-04  6.10333589e-04  5.99709742e-04  5.89266334e-04
#   5.79000407e-04  5.68909047e-04  5.58989385e-04  5.49238594e-04
#   5.39653891e-04  5.30232535e-04  5.20971832e-04  5.11869129e-04
#   5.02921815e-04  4.94127314e-04  4.85483109e-04  4.76986722e-04
#   4.68635712e-04  4.60427673e-04  4.52360233e-04  4.44431059e-04
#   4.36637851e-04  4.28978344e-04  4.21450310e-04  4.14051556e-04
#   4.06779924e-04  3.99633293e-04  3.92609575e-04  3.85706709e-04
#   3.78922686e-04  3.72255526e-04  3.65703278e-04  3.59264021e-04
#   3.52935860e-04  3.46716932e-04  3.40605401e-04  3.34599460e-04
#   3.28697333e-04  3.22897269e-04  3.17197549e-04  3.11596481e-04
#   3.06092400e-04  3.00683668e-04  2.95368684e-04  2.90145871e-04
#   2.85013677e-04  2.79970571e-04  2.75015045e-04  2.70145617e-04
#   2.65360826e-04  2.60659236e-04  2.56039432e-04  2.51500025e-04
#   2.47039647e-04  2.42656955e-04  2.38350625e-04  2.34119359e-04
#   2.29961886e-04  2.25876954e-04  2.21863330e-04  2.17919798e-04
#   2.14045164e-04  2.10238250e-04  2.06497898e-04  2.02822968e-04
#   1.99212340e-04  1.95664912e-04  1.92179601e-04  1.88755342e-04
#   1.85391085e-04  1.82085807e-04  1.78838501e-04  1.75648174e-04
#   1.72513850e-04  1.69434568e-04  1.66409381e-04  1.63437357e-04
#   1.60517581e-04  1.57649151e-04  1.54831181e-04  1.52062800e-04
#   1.49343153e-04  1.46671396e-04  1.44046704e-04  1.41468268e-04
#   1.38935291e-04  1.36446992e-04  1.34002597e-04  1.31601347e-04
#   1.29242496e-04  1.26925308e-04  1.24649059e-04  1.22413040e-04
#   1.20216551e-04  1.18058905e-04  1.15939428e-04  1.13857460e-04]

# %% [markdown]
# ##### 🧩 Compute $\omega_l,\omega_r$ and plot the translation speed of each wheels in km/h

# %%
oml = dOmega_l +v/Rw
omr = dOmega_r +v/Rw

fig=figure(figsize=(15, 15))

plot(t,oml*Rw*3.6)
plot(t,omr*Rw*3.6)
grid()
legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### 🧩 Are these control values consistent with what the robot should do to cancel the error?

# %% [markdown]
# Le robot ajuste la vitesse de ses roues en prenant un certain angle, ce qui lui permet de s'aligner sur l'axe x. Bien qu'il y ait eu une légère phase de réajustement, les valeurs de contrôle utilisées ont permis au robot d'atteindre son objectif.

# %% [markdown]
# ###  Controller Tuning

# %% [markdown]
# ##### 🧩 Tune the poles (and recompute the gain matrix) so that the actual location $(x, y)$ is within 10 cm of the desired location within 20 sec and the linear velocity of each wheel never exceeds $5$ km/h. Plot the values of $\Delta x$ (in m), $\Delta y$ (in m), $\Delta \theta$ (in degrees), and the speed of each wheel (in km/h)

# %%
pass

# %% [markdown]
# ##### 🧩 Simulate the initial, nonlinear wheelchair model when the control law computed in the section "Controller Tuning" is applied. Check that the constraint given for the control law design still hold.

# %%
pass

# %% [markdown]
# ##### 🧩 Display this trajectory using a snapshot of the wheelchair in the plane every second.

# %%
pass
